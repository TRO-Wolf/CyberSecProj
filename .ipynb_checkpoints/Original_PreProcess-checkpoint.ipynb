# %% [markdown]
# # Increasing the Notebook Size

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Importing Native Python Libraries
import os
import math
import random
from collections import namedtuple, deque
from itertools import count

# Importing Numpy and Pandas
import numpy as np
import pandas as pd
# import modin.pandas as pd

# Importing Matplotlib
import matplotlib
import matplotlib.pyplot as plt

# Imorting Numba
from numba import jit

# Importing TA-Lib
import talib

# Importing RL Libraries
import gymnasium as gym

# Importing TQDM to track cell progress
from tqdm import tqdm

# Ignoring Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Code to Initially Import Network Activity Log to Pandas DataFrame

# %% [markdown]
# ## John's Method

# %%
# chunk_size = 100000  # Adjust the chunk size according to your available memory
# chunks = []
# count = 0
# for chunk in pd.read_csv('auth.txt', chunksize=chunk_size):
#     # Process each chunk or store it in a list for later processing
#     chunks.append(chunk)
#     count += 1
#     if count == 2000:
#         break

# # Concatenate the chunks into a single DataFrame if needed
# df = pd.concat(chunks)

# # Renaming all of our column headers
# df = df.rename({'1':'time', 'ANONYMOUS LOGON@C586':'source', 'ANONYMOUS LOGON@C586.1':'dest', 'C1250':'source_pc', 'C586':'dest_pc', 'NTLM':'auth_type', 'Network':'logon_type', 'LogOn':'auth_orient'},axis=1)
# df = df[1:]
# df = df.set_index('time')

# del chunk, chunks # Chunks were only used to build dataframe deleting to help with memory management

# %% [markdown]
# # Visualizing our Initial DataFrame

# %%
# df

# %%
# del df # Memory Management

# %% [markdown]
# # Code to Initially Import CSV Data to Pandas DataFrame

# %% [markdown]
# ## Zach's Method

# %%
# %%time
# df_2 = pd.read_csv("C:/Users/zjshe/Documents/02. ECU MS CS/06. Summer 2023/CSCI 5503 - Intelligent Cloud-based Anomalous Behavior Detection/04. Datasets/Los Alamos Multi_Source Cybersecurity Events/auth.txt", 
#                    sep=",", 
#                    names=['Time Stamp', 'Source User @ Domain', 'Destination User @ Domain', 'Source Computer', 'Source Destination',  'Authentication Type', 'Logon Type', 'Auth Orientation', 'Success/Failure'])

# %%
# Code to Verify Table was uploaded Correctly
# df_2

# %% [markdown]
# # Importing Filetered Data

# %%
# %%time
fd_df = pd.read_csv('./data_files/Fileterd_Data').copy()
# Out:
# CPU times: total: 9.25 s
# Wall time: 9.27 s

# %% [markdown]
# # Importing the Redteam Text to DataFrame

# %%
red_df = pd.read_csv('./data_files/redteam.txt')
red_df = red_df.rename({'150885':'time', 'U620@DOM1':'user_domain', 'C17693':'source_pc', 'C1003':'dest_pc'},axis=1)
red_df = red_df.set_index('time')
red_df
# Out:
#         user_domain source_pc dest_pc
# time
# 151036    U748@DOM1    C17693    C305
# 151648    U748@DOM1    C17693    C728
# 151993   U6115@DOM1    C17693   C1173
# 153792    U636@DOM1    C17693    C294
# 155219    U748@DOM1    C17693   C5693
# ...             ...       ...     ...
# 2552687   U655@DOM1    C17693    C828
# 2552687   U655@DOM1    C17693    C828
# 2552687   U655@DOM1    C17693    C828
# 2552687   U655@DOM1    C17693    C828
# 2557047   U737@DOM1    C19932    C108
#
# [748 rows x 3 columns]

# %%
target_df = red_df[50:250]

# %% [markdown]
# # Creating a List to Find RedTeam Activity in Network Activity Log

# %%
target_array = []
for i in target_df.values:
    result = " ".join(i)
    target_array.append(result)

# %%
target_array
# Out:
# ['U1653@DOM1 C17693 C2669',
#  'U293@DOM1 C17693 C3153',
#  'U8946@DOM1 C17693 C1610',
#  'U293@DOM1 C17693 C3153',
#  'U10379@C3521 C17693 C3521',
#  'U293@DOM1 C17693 C3153',
#  'U8946@DOM1 C17693 C1124',
#  'U293@DOM1 C17693 C3153',
#  'U8946@DOM1 C17693 C3199',
#  'U293@DOM1 C17693 C3153',
#  'U8946@DOM1 C17693 C11727',
#  'U8601@DOM1 C17693 C754',
#  'U212@DOM1 C17693 C126',
#  'U212@DOM1 C17693 C126',
#  'U212@DOM1 C17693 C126',
#  'U8946@DOM1 C17693 C9945',
#  'U8946@DOM1 C17693 C9945',
#  'U8946@DOM1 C17693 C9945',
#  'U4978@DOM1 C17693 C1448',
#  'U8946@DOM1 C17693 C9945',
#  'U3905@DOM1 C17693 C9945',
#  'U995@DOM1 C17693 C1014',
#  'U8601@DOM1 C17693 C20819',
#  'U8601@DOM1 C17693 C20819',
#  'U8601@DOM1 C17693 C18626',
#  'U8601@DOM1 C17693 C18626',
#  'U288@DOM1 C17693 C1222',
#  'U2837@DOM1 C17693 C89',
#  'U2837@DOM1 C17693 C1484',
#  'U2837@DOM1 C17693 C8490',
#  'U349@DOM1 C17693 C3601',
#  'U2837@DOM1 C17693 C1784',
#  'U2837@DOM1 C17693 C1784',
# ...

# %% [markdown]
# # Function to Create One String from a Single Row in Network Activity DF

# %% [markdown]
# Jit is Numba's just-in-time compiler function\
# Numba translates Python functions to optimized machine code at runtime using the industry-standard LLVM compiler library. Numba-compiled numerical algorithms in Python can approach the speeds of C or FORTRAN

# %%
@jit
def get_loop(input_array):
    main_array = []
    for i in input_array:
        result = " ".join(i)
        main_array.append(result)
    return main_array

# %%
fd = fd_df.copy()

# %%
fd.columns
# Out:
# Index(['Unnamed: 0', 'Time Stamp', 'Source User @ Domain',
#        'Destination User @ Domain', 'Source Computer', 'Source Destination',
#        'Authentication Type', 'Logon Type', 'Auth Orientation',
#        'Success/Failure'],
#       dtype='object')

# %% [markdown]
# # Renaming our Filtered Data DataFrame Columns

# %%
fd = fd.rename({
    'Source User @ Domain': 'Source_Dome', 'Destination User @ Domain': 'Dest_Dome', 'Source Computer':'Source_PC', 'Source Destination':'Destination_PC', 
    'Authentication Type':'auth_type', 'Logon Type':'logon_type', 'Success/Failure':'result',
},axis=1)

# Verifying Our Update Column Names
fd
# Out:
#           Unnamed: 0  Time Stamp           Source_Dome             Dest_Dome  \
# 0          137649533      715589  ANONYMOUS LOGON@C457  ANONYMOUS LOGON@C457
# 1          137649534      715589  ANONYMOUS LOGON@C467  ANONYMOUS LOGON@C467
# 2          137649535      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# 3          137649536      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# 4          137649537      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# ...              ...         ...                   ...                   ...
# 14863570   152513103      777813            U8857@DOM1            U8857@DOM1
# 14863571   152513104      777813             U953@DOM1             U953@DOM1
# 14863572   152513105      777813            U9861@DOM1            U9861@DOM1
# 14863573   152513106      777813             U996@DOM1             U996@DOM1
# 14863574   152513107      777813             U996@DOM1             U996@DOM1
#
# ...

# %%
fd[['Source_Dome', 'Source_PC', 'Destination_PC']].values[0]
# Out:
# array(['ANONYMOUS LOGON@C457', 'C457', 'C457'], dtype=object)

# %%
fd['check'] = get_loop(fd[['Source_Dome', 'Source_PC', 'Destination_PC']].values)

# %% [markdown]
# # Checking for Matches Against RedTeam Activity in Network Log

# %% [markdown]
# If a string match is found in our 'check' column against the red team log, then we can mark the 'target' column with a 1 indicating malicious activity.

# %%
# %%time
fd['target'] = fd['check'].apply(lambda x: 1 if x in target_array else 0)
fd
# Out:
# CPU times: total: 22.2 s
# Wall time: 22.4 s
#           Unnamed: 0  Time Stamp           Source_Dome             Dest_Dome  \
# 0          137649533      715589  ANONYMOUS LOGON@C457  ANONYMOUS LOGON@C457
# 1          137649534      715589  ANONYMOUS LOGON@C467  ANONYMOUS LOGON@C467
# 2          137649535      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# 3          137649536      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# 4          137649537      715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586
# ...              ...         ...                   ...                   ...
# 14863570   152513103      777813            U8857@DOM1            U8857@DOM1
# 14863571   152513104      777813             U953@DOM1             U953@DOM1
# 14863572   152513105      777813            U9861@DOM1            U9861@DOM1
# 14863573   152513106      777813             U996@DOM1             U996@DOM1
# 14863574   152513107      777813             U996@DOM1             U996@DOM1
#
# ...

# %%
fd = fd.set_index('Time Stamp')
fd
# Out:
#             Unnamed: 0           Source_Dome             Dest_Dome Source_PC  \
# Time Stamp
# 715589       137649533  ANONYMOUS LOGON@C457  ANONYMOUS LOGON@C457      C457
# 715589       137649534  ANONYMOUS LOGON@C467  ANONYMOUS LOGON@C467      C467
# 715589       137649535  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586      C586
# 715589       137649536  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C5995
# 715589       137649537  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C6931
# ...                ...                   ...                   ...       ...
# 777813       152513103            U8857@DOM1            U8857@DOM1      C528
# 777813       152513104             U953@DOM1             U953@DOM1      C803
# 777813       152513105            U9861@DOM1            U9861@DOM1      C457
# 777813       152513106             U996@DOM1             U996@DOM1       C10
# 777813       152513107             U996@DOM1             U996@DOM1     C3173
#
# ...

# %% [markdown]
# # Saving our DataFrame to a CSV for Later use

# %%
fd.to_csv('./data_files/Full_Data_2.csv')

# %% [markdown]
# # Importing Data with Anomalous Labels

# %%
# %%time
temp = pd.read_csv('./data_files/Full_Data_2.csv')
# Out:
# CPU times: total: 16.3 s
# Wall time: 16.4 s

# %%
temp.columns
temp = temp.drop(['Unnamed: 0','check'],axis=1)
temp
# Out:
#           Time Stamp           Source_Dome             Dest_Dome Source_PC  \
# 0             715589  ANONYMOUS LOGON@C457  ANONYMOUS LOGON@C457      C457
# 1             715589  ANONYMOUS LOGON@C467  ANONYMOUS LOGON@C467      C467
# 2             715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586      C586
# 3             715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C5995
# 4             715589  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C6931
# ...              ...                   ...                   ...       ...
# 14863570      777813            U8857@DOM1            U8857@DOM1      C528
# 14863571      777813             U953@DOM1             U953@DOM1      C803
# 14863572      777813            U9861@DOM1            U9861@DOM1      C457
# 14863573      777813             U996@DOM1             U996@DOM1       C10
# 14863574      777813             U996@DOM1             U996@DOM1     C3173
#
# ...

# %% [markdown]
# # End of Used Jupyter Notebook Book Code

# %% [markdown]
# # All Lines Below This Were For Research and Exploratory Purposes

# %%
temp['result'] = np.where(temp['result']=='Success', 1, 0)

# %%
temp = temp.set_index('Time Stamp')
temp
# Out:
#                      Source_Dome             Dest_Dome Source_PC  \
# Time Stamp
# 715589      ANONYMOUS LOGON@C457  ANONYMOUS LOGON@C457      C457
# 715589      ANONYMOUS LOGON@C467  ANONYMOUS LOGON@C467      C467
# 715589      ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586      C586
# 715589      ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C5995
# 715589      ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586     C6931
# ...                          ...                   ...       ...
# 777813                U8857@DOM1            U8857@DOM1      C528
# 777813                 U953@DOM1             U953@DOM1      C803
# 777813                U9861@DOM1            U9861@DOM1      C457
# 777813                 U996@DOM1             U996@DOM1       C10
# 777813                 U996@DOM1             U996@DOM1     C3173
#
#            Destination_PC auth_type logon_type Auth Orientation  result  \
# Time Stamp
# 715589               C457         ?    Network           LogOff       1
# ...

# %%
temp['Auth Orientation'].value_counts()

# %%
enc = OneHotEncoder()

# %%
train = temp.drop(['target'],axis=1)

# %%
temp

# %%
temp['result']

# %%
new.loc[715599]

# %%
new.loc[715589 + 10]

# %%
new['Source_PC']

# %%
new[
    new['Source_PC'] == 'C17693'
]

# %%
new[ 
    new['target'] == 1
]

# %%
new[
    new['logon_type'] == 'Network'
]

# %%
new[ 
    new['target'] == 1
]['Source_PC'].value_counts()

# %%
new[ 
    new['target'] == 1
]['Destination_PC'].value_counts()

# %%
new[ 
    new['target'] == 0
]['Destination_PC'].value_counts()

# %%
new[ 
    new['target'] == 1
]['auth_type'].value_counts()

# %%
new[ 
    new['target'] == 0
]['auth_type'].value_counts()

# %%
new[ 
    new['target'] == 1
]['Dest_Dome'].value_counts()

# %%
new.index

# %%
new.to_csv('target_data.csv')

# %%
new[
    new['target'] == 1
]

# %%
new['source']

# %%
new['source'].values[0].split()

# %%
test = new.copy()

# %%
test[['user', 'domain']] = df['source'].str.split('@', n=1, expand=True)

# %%
from lightgbm import LGBMClassifier

# %%
model = LGBMClassifier(
    boosting_type='rf',
    num_leaves=440,
    max_depth=21,
    n_estimators=100,
    min_child_samples=10,
    n_jobs=2,
    random_state=5
)

# %%
new['target'].value_counts()

# %%
final_array = []
for i in target_array:
    if i in

# %%
target_array[0] in new['test'].values

# %%
@jit
def get_me(input_array):
    final_array = []
    for i in input_array:

# %%
main

# %%
main_array = []
for i in df[['source', 'source_pc', 'dest_pc']].values:
    result = " ".join(i)
    main_array.append(result)
main_array

# %%
del main_array, i, result

# %%
target_tuple = tuple()
main_tuple = tuple()

# %%
values = []
for i in target.values:
    target_set = set(i)
    for main in df[['source', 'source_pc', 'dest_pc']].values:
        main_set = set(main)
        if target_set == main_set:
            values.append(1)
        else:
            values.append(0)

# %%
main_tuple = tuple()

# %%
new = df.loc[target.index]

# %%
new_target = target.copy()
new_target = target.reset_index()
new_target

# %%
new_target = new_target.set_index('source_pc')
new_target

# %%
new

# %%
new_df = new.copy()

# %%
new_df = new_df.reset_index()
new_df

# %%
new_df = new_df.set_index('source_pc')
new_df

# %%
new_df.loc[new_target.index]

# %%
target

# %%
items = []
for i in new['source_pc'].values:
    for n in target['source_pc'].values:
        if i == n:
            items.append()

# %%
new

# %%
del red 
del df
# del chunks
# del chunk

# %%
del chunks
del chunk
